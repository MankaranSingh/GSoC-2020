# %%
import os
import random
import numpy as np
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# **Change some file names randomly to create some noise in data.**

# %%
directory = os.listdir('./yes')
directory = [file for file in directory if file[-2:] == 'py']
change_name = random.choices(directory, k=10)
change_name
# Out:
# ['test_errors.py',
#  'test_cli.py',
#  'test_interrupt.py',
#  'unicode_literals_test.py',
#  'oserror_aliases_test.py',
#  'versioned_branches_test.py',
#  'raw_unicode_literals_test.py',
#  'test_outdated.py',
#  'open_mode_test.py',
#  'yield_from_test.py']

# %%
for i, file in enumerate(change_name):
    os.rename('./yes/' + file, './yes/' + '58454' + f'{i}' + '.py')

# %%
# recursively scan for files from the root directory

file_paths_yes = []

for subdir, dirs, files in os.walk('.\\yes'):
    for file in files:
        file_paths_yes.append(os.path.join(subdir, file).replace('\\', '/'))

# %%
file_paths_yes
# Out:
# ['./yes/584540.py',
#  './yes/584541.py',
#  './yes/584542.py',
#  './yes/584543.py',
#  './yes/584544.py',
#  './yes/584545.py',
#  './yes/584546.py',
#  './yes/584547.py',
#  './yes/584548.py',
#  './yes/584549.py',
#  './yes/octal_literals_test.py',
#  './yes/percent_format_test.py',
#  './yes/set_literals_test.py',
#  './yes/six_test.py',
#  './yes/super_test.py',
#  './yes/testcase.py',
#  './yes/test_api.py',
#  './yes/test_scancode_checks.py',
#  './yes/test_scan_utils.py',
#  './yes/stuff/binary_literals_test.py',
#  './yes/stuff/conftest.py',
#  './yes/stuff/data.py',
#  './yes/stuff/default_encoding_test.py',
#  './yes/stuff/dict_literals_test.py',
#  './yes/stuff/discovery_test.py',
#  './yes/stuff/encoding_cookie_test.py',
#  './yes/stuff/escape_sequences_test.py',
#  './yes/stuff/extra_parens_test.py',
#  './yes/stuff/file_diff_stat_test.py',
#  './yes/stuff/format_literals_test.py',
#  './yes/stuff/fstrings_test.py',
#  './yes/stuff/__init__ (3).py',
#  './yes/stuff/__init__.py',
#  './yes/testing/test_cli (2).py',
#  './yes/testing/test_common.py',
#  './yes/testing/test_extract_cli.py',
#  './yes/testing/test_plotting.py',
#  './yes/testing/test_plugin_ignore.py',
#  './yes/testing/test_plugin_mark_source.py',
#  './yes/testing/test_plugin_only_findings.py',
#  './yes/testing/test_resource.py',
#  './yes/testing/__init__.py',
#  './yes/testing/assertions/response.py',
#  './yes/testing/assertions/__init__.py',
#  './yes/testing/testing_package/__init__.py',
#  './yes/testing/testing_package/package_a/base.py',
#  './yes/testing/testing_package/package_a/__init__.py',
#  './yes/testing/testing_package/package_b/derived.py',
#  './yes/testing/testing_package/package_b/__init__.py',
#  './yes/testing/utilities/auto_namedtuple.py',
#  './yes/testing/utilities/client.py',
#  './yes/testing/utilities/cwd.py',
#  './yes/testing/utilities/__init__.py',
#  './yes/tests/generate_config_test.py',
#  './yes/tests/generate_test.py',
#  './yes/tests/identity_equality_test.py',
#  './yes/tests/import_removals_test.py',
#  './yes/tests/io_open_test.py',
#  './yes/tests/list_metrics_test.py',
#  './yes/tests/logic_test.py',
#  './yes/tests/long_literals_test.py',
#  './yes/tests/main_test.py',
#  './yes/tests/native_literals_test.py',
#  './yes/tests/new_style_classes_test.py',
#  './yes/tests/repo_parser_test.py',
#  './yes/tests/__init__ (2).py',
#  './yes/tests/metrics/base_test.py',
#  './yes/tests/metrics/binary_file_count_test.py',
#  './yes/tests/metrics/curse_test.py',
#  './yes/tests/metrics/imports_test.py',
#  './yes/tests/metrics/lines_in_init_test.py',
#  './yes/tests/metrics/lines_test.py',
#  './yes/tests/metrics/submodule_count_test.py',
#  './yes/tests/metrics/symlink_count_test.py',
#  './yes/tests/metrics/todo_test.py',
#  './yes/tests/metrics/__init__.py',
#  './yes/tests/server/app_test.py',
#  './yes/tests/server/conftest.py',
#  './yes/tests/server/logic_test.py',
#  './yes/tests/server/metric_config_test.py',
#  './yes/tests/server/__init__.py',
#  './yes/tests/server/presentation/commit_delta_test.py',
#  './yes/tests/server/presentation/delta_test.py',
#  './yes/tests/server/presentation/__init__.py',
#  './yes/tests/server/servlets/changes_test.py',
#  './yes/tests/server/servlets/commit_test.py',
#  './yes/tests/server/servlets/graph_test.py',
#  './yes/tests/server/servlets/index_test.py',
#  './yes/tests/server/servlets/status_test.py',
#  './yes/tests/server/servlets/widget_test.py',
#  './yes/tests/server/servlets/__init__.py',
#  './yes/tests/testing/__init__.py',
#  './yes/tests/testing/assertions/response_test.py',
#  './yes/tests/testing/assertions/__init__.py',
#  './yes/tests/testing/utilities/client_test.py',
#  './yes/tests/testing/utilities/__init__.py',
#  './yes/tests/util/discovery_test.py',
#  './yes/tests/util/iter_test.py',
#  './yes/tests/util/subprocess_test.py',
#  './yes/tests/util/time_test.py',
#  './yes/tests/util/__init__.py']

# %%
# features like ## Features (Test file binary classification) - 'test' in filename, 'test' in absolute path,
# 'test' word count, 'assert' word count, 'testing library imported or not', neighbourhood filenames.

def extract_features_from_file_paths(paths):
    
    filenames = []
    test_in_filename = []
    test_in_directory_path = []
    test_word_count = []
    assert_word_count = []
    testing_library_imported_or_not = []
    test_count_in_neighbouring_filenames = []
    
    for path in paths:
        
        try:
            with open(path, encoding="utf8") as file:
                content = file.read()
                test_word_count.append(content.count('test'))
                assert_word_count.append(content.count('assert'))
                testing_library_imported_or_not.append('importt pytest' in content)
                
        except Exception as e:
            print(path, e)
            continue
            
        filenames.append(os.path.basename(path))
        test_in_filename.append('test' in os.path.basename(path))
        test_in_directory_path.append('test' in os.path.dirname(path))
        
        neighbours = os.listdir(os.path.dirname(path))
        count = 0
        for filename in neighbours:
            if 'test' in filename:
                count += 1
        test_count_in_neighbouring_filenames.append(count)
        
    return pd.DataFrame({'filename':filenames, 'test_in_filename':test_in_filename, 'test_in_directory_path':test_in_directory_path, 'test_word_count':test_word_count, 'assert_word_count':assert_word_count, 'testing_library_imported_or_not':testing_library_imported_or_not, 'test_count_in_neighbouring_filenames':test_count_in_neighbouring_filenames})

# %%
df = extract_features_from_file_paths(file_paths_yes)

# %%
df
# Out:
#                      filename  test_in_filename  test_in_directory_path  \
# 0                   584540.py             False                   False
# 1                   584541.py             False                   False
# 2                   584542.py             False                   False
# 3                   584543.py             False                   False
# 4                   584544.py             False                   False
# 5                   584545.py             False                   False
# 6                   584546.py             False                   False
# 7                   584547.py             False                   False
# 8                   584548.py             False                   False
# 9                   584549.py             False                   False
# 10     octal_literals_test.py              True                   False
# 11     percent_format_test.py              True                   False
# 12       set_literals_test.py              True                   False
# 13                six_test.py              True                   False
# 14              super_test.py              True                   False
# 15                testcase.py              True                   False
# 16                test_api.py              True                   False
# 17    test_scancode_checks.py              True                   False
# 18         test_scan_utils.py              True                   False
# 19    binary_literals_test.py              True                   False
# 20                conftest.py              True                   False
# 21                    data.py             False                   False
# 22   default_encoding_test.py              True                   False
# 23      dict_literals_test.py              True                   False
# 24          discovery_test.py              True                   False
# 25    encoding_cookie_test.py              True                   False
# 26   escape_sequences_test.py              True                   False
# 27       extra_parens_test.py              True                   False
# 28     file_diff_stat_test.py              True                   False
# 29    format_literals_test.py              True                   False
# ..                        ...               ...                     ...
# 71              lines_test.py              True                    True
# 72    submodule_count_test.py              True                    True
# 73      symlink_count_test.py              True                    True
# 74               todo_test.py              True                    True
# 75                __init__.py             False                    True
# 76                app_test.py              True                    True
# 77                conftest.py              True                    True
# 78              logic_test.py              True                    True
# 79      metric_config_test.py              True                    True
# 80                __init__.py             False                    True
# 81       commit_delta_test.py              True                    True
# 82              delta_test.py              True                    True
# 83                __init__.py             False                    True
# 84            changes_test.py              True                    True
# 85             commit_test.py              True                    True
# 86              graph_test.py              True                    True
# 87              index_test.py              True                    True
# 88             status_test.py              True                    True
# 89             widget_test.py              True                    True
# 90                __init__.py             False                    True
# 91                __init__.py             False                    True
# 92           response_test.py              True                    True
# 93                __init__.py             False                    True
# 94             client_test.py              True                    True
# 95                __init__.py             False                    True
# 96          discovery_test.py              True                    True
# 97               iter_test.py              True                    True
# 98         subprocess_test.py              True                    True
# 99               time_test.py              True                    True
# 100               __init__.py             False                    True
#
#      test_word_count  assert_word_count  testing_library_imported_or_not  \
# 0                 34                  2                            False
# 1                 15                 21                            False
# 2                  8                  9                            False
# 3                  8                  3                            False
# 4                 18                  6                            False
# 5                 35                  3                            False
# 6                  9                  2                            False
# 7                 20                  5                            False
# 8                  5                  2                            False
# 9                  7                  6                            False
# 10                 5                  2                            False
# 11                18                  8                            False
# 12                 9                  3                            False
# 13                26                 11                            False
# 14                 5                  2                            False
# 15               154                  5                            False
# 16                55                 15                            False
# 17                14                  0                            False
# 18                42                 17                            False
# 19                 5                  2                            False
# 20                 9                  0                            False
# 21                 1                  0                            False
# 22                 5                  2                            False
# 23                 5                  2                            False
# 24                17                 10                            False
# 25                 7                  2                            False
# 26                 5                  2                            False
# 27                 6                  2                            False
# 28                19                 19                            False
# 29                 9                  4                            False
# ..               ...                ...                              ...
# 71                 2                  1                            False
# 72                 3                  3                            False
# 73                 3                  3                            False
# 74                 1                  1                            False
# 75                 0                  0                            False
# 76                 5                  3                            False
# 77                11                  0                            False
# 78                 4                  4                            False
# 79                16                 13                            False
# 80                 0                  0                            False
# 81                 3                  2                            False
# 82                 3                  3                            False
# 83                 0                  0                            False
# 84                 2                  5                            False
# 85                 3                  5                            False
# 86                10                 14                            False
# 87                 8                  7                            False
# 88                 1                  0                            False
# 89                 9                  8                            False
# 90                 0                  0                            False
# 91                 0                  0                            False
# 92                16                 11                            False
# 93                 0                  0                            False
# 94                12                  3                            False
# 95                 0                  0                            False
# 96                12                  2                            False
# 97                 3                  1                            False
# 98                 5                  4                            False
# 99                 3                  3                            False
# 100                0                  0                            False
#
#      test_count_in_neighbouring_filenames
# 0                                      11
# 1                                      11
# 2                                      11
# 3                                      11
# 4                                      11
# 5                                      11
# 6                                      11
# 7                                      11
# 8                                      11
# 9                                      11
# 10                                     11
# 11                                     11
# 12                                     11
# 13                                     11
# 14                                     11
# 15                                     11
# 16                                     11
# 17                                     11
# 18                                     11
# 19                                     11
# 20                                     11
# 21                                     11
# 22                                     11
# 23                                     11
# 24                                     11
# 25                                     11
# 26                                     11
# 27                                     11
# 28                                     11
# 29                                     11
# ..                                    ...
# 71                                      9
# 72                                      9
# 73                                      9
# 74                                      9
# 75                                      9
# 76                                      4
# 77                                      4
# 78                                      4
# 79                                      4
# 80                                      4
# 81                                      2
# 82                                      2
# 83                                      2
# 84                                      6
# 85                                      6
# 86                                      6
# 87                                      6
# 88                                      6
# 89                                      6
# 90                                      6
# 91                                      0
# 92                                      1
# 93                                      1
# 94                                      1
# 95                                      1
# 96                                      4
# 97                                      4
# 98                                      4
# 99                                      4
# 100                                     4
#
# [101 rows x 7 columns]

# %%
# Similarly, exted the dataset for the 'not test file' labels

file_paths_no = []

for subdir, dirs, files in os.walk('.\\no'):
    for file in files:
        file_paths_no.append(os.path.join(subdir, file).replace('\\', '/'))

# %%
file_paths_no = file_paths_no[:150]
file_paths_no
# Out:
# ['./no/ (2).gitignore',
#  './no/pyupgrade.py',
#  './no/README (2).md',
#  './no/README.md',
#  './no/requirements-dev.txt',
#  './no/requirements.txt',
#  './no/setup.py',
#  './no/test.cfg',
#  './no/test1.py',
#  './no/test2.cfg',
#  './no/tox.ini',
#  './no/camelot/cli.py',
#  './no/camelot/core.py',
#  './no/camelot/handlers.py',
#  './no/camelot/image_processing.py',
#  './no/camelot/io.py',
#  './no/camelot/plotting.py',
#  './no/camelot/utils.py',
#  './no/camelot/__init__.py',
#  './no/camelot/__main__.py',
#  './no/camelot/__version__.py',
#  './no/camelot/ext/__init__.py',
#  './no/camelot/ext/ghostscript/COPYING',
#  './no/camelot/ext/ghostscript/_gsprint.py',
#  './no/camelot/ext/ghostscript/__init__.py',
#  './no/camelot/parsers/base.py',
#  './no/camelot/parsers/lattice.py',
#  './no/camelot/parsers/stream.py',
#  './no/camelot/parsers/__init__.py',
#  './no/docs/api.rst',
#  './no/docs/conf.py',
#  './no/docs/index.rst',
#  './no/docs/make.bat',
#  './no/docs/Makefile',
#  './no/docs/benchmark/lattice/agstat/agstat-data-camelot-page-1-table-1.csv',
#  './no/docs/benchmark/lattice/agstat/agstat-data-pdf-table-extract-page-1-table-1.csv',
#  './no/docs/benchmark/lattice/agstat/agstat-data-pdfplumber.csv',
#  './no/docs/benchmark/lattice/agstat/agstat-data-pdftables-page-1-table-1.csv',
#  './no/docs/benchmark/lattice/agstat/agstat-data-tabula.csv',
#  './no/docs/benchmark/lattice/agstat/agstat-table-detection-camelot.png',
#  './no/docs/benchmark/lattice/agstat/agstat-table-detection-tabula.png',
#  './no/docs/benchmark/lattice/agstat/agstat.pdf',
#  './no/docs/benchmark/lattice/background_lines_1/background_lines_1-data-camelot-page-1-table-1.csv',
#  './no/docs/benchmark/lattice/background_lines_1/background_lines_1-data-camelot-page-1-table-2.csv',
#  './no/docs/benchmark/lattice/background_lines_1/background_lines_1-data-tabula.csv',
#  './no/docs/benchmark/lattice/background_lines_1/background_lines_1-table-detection-camelot.png',
#  './no/docs/benchmark/lattice/background_lines_1/background_lines_1-table-detection-tabula.png',
#  './no/docs/benchmark/lattice/background_lines_1/background_lines_1.pdf',
#  './no/docs/benchmark/lattice/background_lines_2/background_lines_2-data-camelot-page-1-table-1.csv',
#  './no/docs/benchmark/lattice/background_lines_2/background_lines_2-data-tabula.csv',
#  './no/docs/benchmark/lattice/background_lines_2/background_lines_2-table-detection-camelot.png',
#  './no/docs/benchmark/lattice/background_lines_2/background_lines_2-table-detection-tabula.png',
#  './no/docs/benchmark/lattice/background_lines_2/background_lines_2.pdf',
#  './no/docs/benchmark/lattice/column_span_1/column_span_1-data-camelot-page-1-table-1.csv',
#  './no/docs/benchmark/lattice/column_span_1/column_span_1-data-pdf-table-extract-page-1-table-1.csv',
#  './no/docs/benchmark/lattice/column_span_1/column_span_1-data-pdfplumber.csv',
#  './no/docs/benchmark/lattice/column_span_1/column_span_1-data-pdftables-page-1-table-1.csv',
#  './no/docs/benchmark/lattice/column_span_1/column_span_1-data-tabula.csv',
#  './no/docs/benchmark/lattice/column_span_1/column_span_1-table-detection-camelot.png',
#  './no/docs/benchmark/lattice/column_span_1/column_span_1-table-detection-tabula.png',
#  './no/docs/benchmark/lattice/column_span_1/column_span_1.pdf',
#  './no/docs/benchmark/lattice/column_span_2/column_span_2-data-camelot-page-1-table-1.csv',
#  './no/docs/benchmark/lattice/column_span_2/column_span_2-data-tabula.csv',
#  './no/docs/benchmark/lattice/column_span_2/column_span_2-table-detection-camelot.png',
#  './no/docs/benchmark/lattice/column_span_2/column_span_2-table-detection-tabula.png',
#  './no/docs/benchmark/lattice/column_span_2/column_span_2.pdf',
#  './no/docs/benchmark/lattice/electoral_roll/electoral_roll-data-camelot-page-1-table-1.csv',
#  './no/docs/benchmark/lattice/electoral_roll/electoral_roll-data-tabula.csv',
#  './no/docs/benchmark/lattice/electoral_roll/electoral_roll-table-detection-camelot.png',
#  './no/docs/benchmark/lattice/electoral_roll/electoral_roll-table-detection-tabula.png',
#  './no/docs/benchmark/lattice/electoral_roll/electoral_roll.pdf',
#  './no/docs/benchmark/lattice/rotated/rotated-data-camelot-page-1-table-1.csv',
#  './no/docs/benchmark/lattice/rotated/rotated-data-pdf-table-extract-page-1-table-1.csv',
#  './no/docs/benchmark/lattice/rotated/rotated-data-pdfplumber.csv',
#  './no/docs/benchmark/lattice/rotated/rotated-data-pdftables-page-1-table-1.csv',
#  './no/docs/benchmark/lattice/rotated/rotated-data-tabula.csv',
#  './no/docs/benchmark/lattice/rotated/rotated-table-detection-camelot.png',
#  './no/docs/benchmark/lattice/rotated/rotated-table-detection-tabula.png',
#  './no/docs/benchmark/lattice/rotated/rotated.pdf',
#  './no/docs/benchmark/lattice/row_span/row_span-data-camelot-page-1-table-1.csv',
#  './no/docs/benchmark/lattice/row_span/row_span-data-tabula.csv',
#  './no/docs/benchmark/lattice/row_span/row_span-table-detection-camelot.png',
#  './no/docs/benchmark/lattice/row_span/row_span-table-detection-tabula.png',
#  './no/docs/benchmark/lattice/row_span/row_span.pdf',
#  './no/docs/benchmark/lattice/twotables_1/twotables_1-data-camelot-page-1-table-1.csv',
#  './no/docs/benchmark/lattice/twotables_1/twotables_1-data-camelot-page-1-table-2.csv',
#  './no/docs/benchmark/lattice/twotables_1/twotables_1-data-pdf-table-extract-page-1-table-1.csv',
#  './no/docs/benchmark/lattice/twotables_1/twotables_1-data-pdfplumber.csv',
#  './no/docs/benchmark/lattice/twotables_1/twotables_1-data-pdftables-page-1-table-1.csv',
#  './no/docs/benchmark/lattice/twotables_1/twotables_1-data-tabula.csv',
#  './no/docs/benchmark/lattice/twotables_1/twotables_1-table-detection-camelot.png',
#  './no/docs/benchmark/lattice/twotables_1/twotables_1-table-detection-tabula.png',
#  './no/docs/benchmark/lattice/twotables_1/twotables_1.pdf',
#  './no/docs/benchmark/lattice/twotables_2/twotables_2-data-camelot-page-1-table-1.csv',
#  './no/docs/benchmark/lattice/twotables_2/twotables_2-data-camelot-page-1-table-2.csv',
#  './no/docs/benchmark/lattice/twotables_2/twotables_2-data-pdf-table-extract-page-1-table-1.csv',
#  './no/docs/benchmark/lattice/twotables_2/twotables_2-data-pdfplumber.csv',
#  './no/docs/benchmark/lattice/twotables_2/twotables_2-data-pdftables-page-1-table-1.csv',
#  './no/docs/benchmark/lattice/twotables_2/twotables_2-table-detection-camelot.png',
#  './no/docs/benchmark/lattice/twotables_2/twotables_2-table-detection-tabula.png',
#  './no/docs/benchmark/lattice/twotables_2/twotables_2-tabula-0.csv',
#  './no/docs/benchmark/lattice/twotables_2/twotables_2-tabula-1.csv',
#  './no/docs/benchmark/lattice/twotables_2/twotables_2.pdf',
#  './no/docs/benchmark/stream/12s0324/12s0324-data-camelot-page-1-table-1.csv',
#  './no/docs/benchmark/stream/12s0324/12s0324-data-camelot-page-1-table-2.csv',
#  './no/docs/benchmark/stream/12s0324/12s0324-data-tabula-0.csv',
#  './no/docs/benchmark/stream/12s0324/12s0324-data-tabula-1.csv',
#  './no/docs/benchmark/stream/12s0324/12s0324.pdf',
#  './no/docs/benchmark/stream/birdisland/birdisland-data-camelot-page-1-table-1.csv',
#  './no/docs/benchmark/stream/birdisland/birdisland-data-camelot-page-1-table-2.csv',
#  './no/docs/benchmark/stream/birdisland/birdisland-data-tabula.csv',
#  './no/docs/benchmark/stream/birdisland/birdisland.pdf',
#  './no/docs/benchmark/stream/budget/budget-data-camelot-page-1-table-1.csv',
#  './no/docs/benchmark/stream/budget/budget-data-pdf-table-extract-page-1-table-1.csv',
#  './no/docs/benchmark/stream/budget/budget-data-pdftables-page-1-table-1.csv',
#  './no/docs/benchmark/stream/budget/budget-data-tabula.csv',
#  './no/docs/benchmark/stream/budget/budget.pdf',
#  './no/docs/benchmark/stream/district_health/district_health-data-camelot-page-1-table-1.csv',
#  './no/docs/benchmark/stream/district_health/district_health-data-pdf-table-extract-page-1-table-1.csv',
#  './no/docs/benchmark/stream/district_health/district_health-data-pdfplumber.csv',
#  './no/docs/benchmark/stream/district_health/district_health-data-pdftables-page-1-table-1.csv',
#  './no/docs/benchmark/stream/district_health/district_health-data-tabula.csv',
#  './no/docs/benchmark/stream/district_health/district_health.pdf',
#  './no/docs/benchmark/stream/health/health-data-camelot-page-1-table-1.csv',
#  './no/docs/benchmark/stream/health/health-data-pdf-table-extract-page-1-table-1.csv',
#  './no/docs/benchmark/stream/health/health-data-pdfplumber.csv',
#  './no/docs/benchmark/stream/health/health-data-pdftables-page-1-table-1.csv',
#  './no/docs/benchmark/stream/health/health-data-tabula.csv',
#  './no/docs/benchmark/stream/health/health.pdf',
#  './no/docs/benchmark/stream/m27/m27-data-camelot-page-1-table-1.csv',
#  './no/docs/benchmark/stream/m27/m27-data-tabula-0.csv',
#  './no/docs/benchmark/stream/m27/m27.pdf',
#  './no/docs/benchmark/stream/mexican_towns/mexican_towns-data-camelot-page-1-table-1.csv',
#  './no/docs/benchmark/stream/mexican_towns/mexican_towns-data-pdf-table-extract-page-1-table-1.csv',
#  './no/docs/benchmark/stream/mexican_towns/mexican_towns-data-pdftables-page-1-table-1.csv',
#  './no/docs/benchmark/stream/mexican_towns/mexican_towns-data-tabula.csv',
#  './no/docs/benchmark/stream/mexican_towns/mexican_towns.pdf',
#  './no/docs/benchmark/stream/missing_values/missing_values-data-camelot-page-1-table-1.csv',
#  './no/docs/benchmark/stream/missing_values/missing_values-data-pdf-table-extract-page-1-table-1.csv',
#  './no/docs/benchmark/stream/missing_values/missing_values-data-pdfplumber.csv',
#  './no/docs/benchmark/stream/missing_values/missing_values-data-pdftables-page-1-table-1.csv',
#  './no/docs/benchmark/stream/missing_values/missing_values-data-tabula.csv',
#  './no/docs/benchmark/stream/missing_values/missing_values.pdf',
#  './no/docs/benchmark/stream/population_growth/population_growth-data-camelot-page-1-table-1.csv',
#  './no/docs/benchmark/stream/population_growth/population_growth-data-tabula.csv',
#  './no/docs/benchmark/stream/population_growth/population_growth.pdf',
#  './no/docs/benchmark/stream/superscript/superscript-data-camelot-page-1-table-1.csv',
#  './no/docs/benchmark/stream/superscript/superscript-data-tabula.csv',
#  './no/docs/benchmark/stream/superscript/superscript.pdf',
#  './no/docs/benchmark/stream/us-007/us-007-data-camelot-page-1-table-1.csv']

# %%
df_no = extract_features_from_file_paths(file_paths_no)
# Out:
# ./no/docs/benchmark/lattice/agstat/agstat-table-detection-camelot.png 'utf-8' codec can't decode byte 0x89 in position 0: invalid start byte
# ./no/docs/benchmark/lattice/agstat/agstat-table-detection-tabula.png 'utf-8' codec can't decode byte 0x89 in position 0: invalid start byte
# ./no/docs/benchmark/lattice/agstat/agstat.pdf 'utf-8' codec can't decode byte 0xe2 in position 10: invalid continuation byte
# ./no/docs/benchmark/lattice/background_lines_1/background_lines_1-table-detection-camelot.png 'utf-8' codec can't decode byte 0x89 in position 0: invalid start byte
# ./no/docs/benchmark/lattice/background_lines_1/background_lines_1-table-detection-tabula.png 'utf-8' codec can't decode byte 0x89 in position 0: invalid start byte
# ./no/docs/benchmark/lattice/background_lines_1/background_lines_1.pdf 'utf-8' codec can't decode byte 0xa1 in position 11: invalid start byte
# ./no/docs/benchmark/lattice/background_lines_2/background_lines_2-table-detection-camelot.png 'utf-8' codec can't decode byte 0x89 in position 0: invalid start byte
# ./no/docs/benchmark/lattice/background_lines_2/background_lines_2-table-detection-tabula.png 'utf-8' codec can't decode byte 0x89 in position 0: invalid start byte
# ./no/docs/benchmark/lattice/background_lines_2/background_lines_2.pdf 'utf-8' codec can't decode byte 0xa1 in position 11: invalid start byte
# ./no/docs/benchmark/lattice/column_span_1/column_span_1-table-detection-camelot.png 'utf-8' codec can't decode byte 0x89 in position 0: invalid start byte
# ./no/docs/benchmark/lattice/column_span_1/column_span_1-table-detection-tabula.png 'utf-8' codec can't decode byte 0x89 in position 0: invalid start byte
# ./no/docs/benchmark/lattice/column_span_1/column_span_1.pdf 'utf-8' codec can't decode byte 0xa1 in position 11: invalid start byte
# ./no/docs/benchmark/lattice/column_span_2/column_span_2-table-detection-camelot.png 'utf-8' codec can't decode byte 0x89 in position 0: invalid start byte
# ./no/docs/benchmark/lattice/column_span_2/column_span_2-table-detection-tabula.png 'utf-8' codec can't decode byte 0x89 in position 0: invalid start byte
# ./no/docs/benchmark/lattice/column_span_2/column_span_2.pdf 'utf-8' codec can't decode byte 0xe2 in position 10: invalid continuation byte
# ./no/docs/benchmark/lattice/electoral_roll/electoral_roll-table-detection-camelot.png 'utf-8' codec can't decode byte 0x89 in position 0: invalid start byte
# ./no/docs/benchmark/lattice/electoral_roll/electoral_roll-table-detection-tabula.png 'utf-8' codec can't decode byte 0x89 in position 0: invalid start byte
# ./no/docs/benchmark/lattice/electoral_roll/electoral_roll.pdf 'utf-8' codec can't decode byte 0xa7 in position 10: invalid start byte
# ./no/docs/benchmark/lattice/rotated/rotated-table-detection-camelot.png 'utf-8' codec can't decode byte 0x89 in position 0: invalid start byte
# ./no/docs/benchmark/lattice/rotated/rotated-table-detection-tabula.png 'utf-8' codec can't decode byte 0x89 in position 0: invalid start byte
# ./no/docs/benchmark/lattice/rotated/rotated.pdf 'utf-8' codec can't decode byte 0xa1 in position 11: invalid start byte
# ./no/docs/benchmark/lattice/row_span/row_span-table-detection-camelot.png 'utf-8' codec can't decode byte 0x89 in position 0: invalid start byte
# ./no/docs/benchmark/lattice/row_span/row_span-table-detection-tabula.png 'utf-8' codec can't decode byte 0x89 in position 0: invalid start byte
# ./no/docs/benchmark/lattice/row_span/row_span.pdf 'utf-8' codec can't decode byte 0xe2 in position 10: invalid continuation byte
# ./no/docs/benchmark/lattice/twotables_1/twotables_1-table-detection-camelot.png 'utf-8' codec can't decode byte 0x89 in position 0: invalid start byte
# ./no/docs/benchmark/lattice/twotables_1/twotables_1-table-detection-tabula.png 'utf-8' codec can't decode byte 0x89 in position 0: invalid start byte
# ./no/docs/benchmark/lattice/twotables_1/twotables_1.pdf 'utf-8' codec can't decode byte 0xa1 in position 11: invalid start byte
# ./no/docs/benchmark/lattice/twotables_2/twotables_2-table-detection-camelot.png 'utf-8' codec can't decode byte 0x89 in position 0: invalid start byte
# ./no/docs/benchmark/lattice/twotables_2/twotables_2-table-detection-tabula.png 'utf-8' codec can't decode byte 0x89 in position 0: invalid start byte
# ./no/docs/benchmark/lattice/twotables_2/twotables_2.pdf 'utf-8' codec can't decode byte 0xa1 in position 11: invalid start byte
# ./no/docs/benchmark/stream/12s0324/12s0324.pdf 'utf-8' codec can't decode byte 0xe2 in position 10: invalid continuation byte
# ./no/docs/benchmark/stream/birdisland/birdisland.pdf 'utf-8' codec can't decode byte 0xe2 in position 10: invalid continuation byte
# ./no/docs/benchmark/stream/budget/budget.pdf 'utf-8' codec can't decode byte 0xa1 in position 11: invalid start byte
# ./no/docs/benchmark/stream/district_health/district_health.pdf 'utf-8' codec can't decode byte 0xa1 in position 11: invalid start byte
# ./no/docs/benchmark/stream/health/health.pdf 'utf-8' codec can't decode byte 0xe2 in position 10: invalid continuation byte
# ./no/docs/benchmark/stream/m27/m27.pdf 'utf-8' codec can't decode byte 0xe2 in position 10: invalid continuation byte
# ./no/docs/benchmark/stream/mexican_towns/mexican_towns.pdf 'utf-8' codec can't decode byte 0xe2 in position 10: invalid continuation byte
# ./no/docs/benchmark/stream/missing_values/missing_values.pdf 'utf-8' codec can't decode byte 0xa1 in position 11: invalid start byte
# ./no/docs/benchmark/stream/population_growth/population_growth.pdf 'utf-8' codec can't decode byte 0xa1 in position 11: invalid start byte
# ./no/docs/benchmark/stream/superscript/superscript.pdf 'utf-8' codec can't decode byte 0xe2 in position 10: invalid continuation byte

# %%
df_no
# Out:
#                                               filename  test_in_filename  \
# 0                                        (2).gitignore             False
# 1                                         pyupgrade.py             False
# 2                                        README (2).md             False
# 3                                            README.md             False
# 4                                 requirements-dev.txt             False
# 5                                     requirements.txt             False
# 6                                             setup.py             False
# 7                                             test.cfg              True
# 8                                             test1.py              True
# 9                                            test2.cfg              True
# 10                                             tox.ini             False
# 11                                              cli.py             False
# 12                                             core.py             False
# 13                                         handlers.py             False
# 14                                 image_processing.py             False
# 15                                               io.py             False
# 16                                         plotting.py             False
# 17                                            utils.py             False
# 18                                         __init__.py             False
# 19                                         __main__.py             False
# 20                                      __version__.py             False
# 21                                         __init__.py             False
# 22                                             COPYING             False
# 23                                         _gsprint.py             False
# 24                                         __init__.py             False
# 25                                             base.py             False
# 26                                          lattice.py             False
# 27                                           stream.py             False
# 28                                         __init__.py             False
# 29                                             api.rst             False
# ..                                                 ...               ...
# 80              budget-data-camelot-page-1-table-1.csv             False
# 81    budget-data-pdf-table-extract-page-1-table-1.csv             False
# 82            budget-data-pdftables-page-1-table-1.csv             False
# 83                              budget-data-tabula.csv             False
# 84     district_health-data-camelot-page-1-table-1.csv             False
# 85   district_health-data-pdf-table-extract-page-1-...             False
# 86                 district_health-data-pdfplumber.csv             False
# 87   district_health-data-pdftables-page-1-table-1.csv             False
# 88                     district_health-data-tabula.csv             False
# 89              health-data-camelot-page-1-table-1.csv             False
# 90    health-data-pdf-table-extract-page-1-table-1.csv             False
# 91                          health-data-pdfplumber.csv             False
# 92            health-data-pdftables-page-1-table-1.csv             False
# 93                              health-data-tabula.csv             False
# 94                 m27-data-camelot-page-1-table-1.csv             False
# 95                               m27-data-tabula-0.csv             False
# 96       mexican_towns-data-camelot-page-1-table-1.csv             False
# 97   mexican_towns-data-pdf-table-extract-page-1-ta...             False
# 98     mexican_towns-data-pdftables-page-1-table-1.csv             False
# 99                       mexican_towns-data-tabula.csv             False
# 100     missing_values-data-camelot-page-1-table-1.csv             False
# 101  missing_values-data-pdf-table-extract-page-1-t...             False
# 102                 missing_values-data-pdfplumber.csv             False
# 103   missing_values-data-pdftables-page-1-table-1.csv             False
# 104                     missing_values-data-tabula.csv             False
# 105  population_growth-data-camelot-page-1-table-1.csv             False
# 106                  population_growth-data-tabula.csv             False
# 107        superscript-data-camelot-page-1-table-1.csv             False
# 108                        superscript-data-tabula.csv             False
# 109             us-007-data-camelot-page-1-table-1.csv             False
#
#      test_in_directory_path  test_word_count  assert_word_count  \
# 0                     False                1                  0
# 1                     False               31                 18
# 2                     False                2                  6
# 3                     False                4                  0
# 4                     False                1                  0
# 5                     False                0                  0
# 6                     False                5                  0
# 7                     False                5                  0
# 8                     False                0                  0
# 9                     False                2                  0
# 10                    False                4                  0
# 11                    False                0                  0
# 12                    False                0                  0
# 13                    False                0                  0
# 14                    False                0                  0
# 15                    False                0                  0
# 16                    False                0                  0
# 17                    False                2                  0
# 18                    False                0                  0
# 19                    False                0                  0
# 20                    False                0                  0
# 21                    False                0                  0
# 22                    False                1                  1
# 23                    False                0                  0
# 24                    False                0                  0
# 25                    False                0                  0
# 26                    False                0                  0
# 27                    False                0                  0
# 28                    False                0                  0
# 29                    False                0                  0
# ..                      ...              ...                ...
# 80                    False                0                  0
# 81                    False                0                  0
# 82                    False                0                  0
# 83                    False                0                  0
# 84                    False                2                  0
# 85                    False                2                  0
# 86                    False                2                  0
# 87                    False                3                  0
# 88                    False                2                  0
# 89                    False                0                  0
# 90                    False                0                  0
# 91                    False                0                  0
# 92                    False                0                  0
# 93                    False                0                  0
# 94                    False                0                  0
# 95                    False                0                  0
# 96                    False                0                  0
# 97                    False                0                  0
# 98                    False                0                  0
# 99                    False                0                  0
# 100                   False                0                  0
# 101                   False                0                  0
# 102                   False                0                  0
# 103                   False                0                  0
# 104                   False                0                  0
# 105                   False                0                  0
# 106                   False                0                  0
# 107                   False                0                  0
# 108                   False                0                  0
# 109                   False                0                  0
#
#      testing_library_imported_or_not  test_count_in_neighbouring_filenames
# 0                              False                                     4
# 1                              False                                     4
# 2                              False                                     4
# 3                              False                                     4
# 4                              False                                     4
# 5                              False                                     4
# 6                              False                                     4
# 7                              False                                     4
# 8                              False                                     4
# 9                              False                                     4
# 10                             False                                     4
# 11                             False                                     0
# 12                             False                                     0
# 13                             False                                     0
# 14                             False                                     0
# 15                             False                                     0
# 16                             False                                     0
# 17                             False                                     0
# 18                             False                                     0
# 19                             False                                     0
# 20                             False                                     0
# 21                             False                                     0
# 22                             False                                     0
# 23                             False                                     0
# 24                             False                                     0
# 25                             False                                     0
# 26                             False                                     0
# 27                             False                                     0
# 28                             False                                     0
# 29                             False                                     0
# ..                               ...                                   ...
# 80                             False                                     0
# 81                             False                                     0
# 82                             False                                     0
# 83                             False                                     0
# 84                             False                                     0
# 85                             False                                     0
# 86                             False                                     0
# 87                             False                                     0
# 88                             False                                     0
# 89                             False                                     0
# 90                             False                                     0
# 91                             False                                     0
# 92                             False                                     0
# 93                             False                                     0
# 94                             False                                     0
# 95                             False                                     0
# 96                             False                                     0
# 97                             False                                     0
# 98                             False                                     0
# 99                             False                                     0
# 100                            False                                     0
# 101                            False                                     0
# 102                            False                                     0
# 103                            False                                     0
# 104                            False                                     0
# 105                            False                                     0
# 106                            False                                     0
# 107                            False                                     0
# 108                            False                                     0
# 109                            False                                     0
#
# [110 rows x 7 columns]

# %%
# Set the true labels 

df['label'] = [True]*len(df)
df_no['label'] = [False]*len(df_no)

# %%
# convert boolean dtypes to int (this is a hack trick)

df = df*1
df_no = df_no*1

# %%
dataset = pd.concat([df, df_no], axis=0)

# %%
from sklearn.model_selection import train_test_split

Train, Test = train_test_split(dataset, test_size=0.5)

# %%
pd.value_counts(Train['label']).plot.bar()

# %%
pd.value_counts(Test['label']).plot.bar(color='R')

# %%
filenames_train = Train.pop('filename') 
filenames_test = Test.pop('filename')

# %%
y_train = Train.pop('label') 
y_test = Test.pop('label')

# %%
from sklearn.svm import SVC

svclassifier = SVC(kernel='linear')
svclassifier.fit(Train, y_train)
# Out:
# SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto', kernel='linear',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)

# %%
y_pred = svclassifier.predict(Test)

# %%
#Import scikit-learn metrics module for accuracy calculation
from sklearn import metrics

print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 1.0

# %% [markdown]
# # Final Thoughts:
#
#
# - The model always gives 100 % accuracy, this means that machine leaning for binary classification of test/non test files is a simple task and can be solved via heuristics approach too.
#
# - The accuracy may vary if we include other project structures (like C/C++, JavaScript, Flutter, etc.)
#
# - A more detailed analysis upon classification of file purpose via single model is in progress
